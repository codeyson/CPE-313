# %% [markdown]
# # Test Python Notebook

# %% [markdown]
# print("Hello World")

# %%
print("hello, mom")
# Out:
# hello, mom

# %%
Git Commands:
- git clone
- git config
- git add, commit, push
- git pull, fetch


commits messages:
feat:
fix:
chore:
refactor:
